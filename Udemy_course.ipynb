# %% [markdown]
# ## - These are the questions.
# - Q. 1) What are all different subjects for which Udemy is offering courses ?
# - Q. 2) Which subject has the maximum number of courses.
# - Q. 3) Show all the courses which are Free of Cost.
# - Q. 4) Show all the courses which are Paid.
# - Q. 5) Which are Top Selling Courses ?
# - Q. 6) Which are Least Selling Courses ?
# - Q. 7) Show all courses of Graphic Design where the price is below 100 ?
# - Q. 8) List out all the courses that are related to 'Python'.
# - Q. 9) What are courses that were published in the year 2015 ?
# - Q. 10) What is the Max. Number of Subscribers for Each Level of courses ?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Udemy Courses.csv",index_col=0)

# %%
df
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 288942     #1 Piano Hand Coordination: Play 10th Ballad i...     True    35
# 1170074    #10 Hand Coordination - Transfer Chord Ballad ...     True    75
# 1193886    #12 Hand Coordination: Let your Hands dance wi...     True    75
# 1116700    #4 Piano Hand Coordination: Fun Piano Runs in ...     True    75
# 1120410    #5  Piano Hand Coordination:  Piano Runs in 2 ...     True    75
# ...                                                      ...      ...   ...
# 328960     Your Own Site in 45 Min: The Complete Wordpres...     True   120
# 552700       Your Second Course on Piano: Two Handed Playing     True    70
# 631754     Zend Framework 2: Learn the PHP framework ZF2 ...     True    40
# 1225194    Zoho Books Gestion Financière d'Entreprise pas...    False  Free
# 964478                   Zombie Apocalypse Photoshop Actions     True    50
#
#            num_subscribers  num_reviews  num_lectures               level  \
# course_id
# 288942                3137           18            68          All Levels
# 1170074               1593            1            41  Intermediate Level
# 1193886                482            1            47  Intermediate Level
# 1116700                850            3            43  Intermediate Level
# 1120410                940            3            32  Intermediate Level
# ...                    ...          ...           ...                 ...
# 328960                1566           29            36          All Levels
# 552700                1018           12            22      Beginner Level
# 631754                 723          130            37          All Levels
# 1225194                229            0            33          All Levels
# 964478                  12            1            15          All Levels
#
#           content_duration   published_timestamp              subject
# course_id
# 288942           1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1170074             1 hour  2017-04-12T19:06:34Z  Musical Instruments
# 1193886          1.5 hours  2017-04-26T18:34:57Z  Musical Instruments
# 1116700             1 hour  2017-02-21T23:48:18Z  Musical Instruments
# 1120410            37 mins  2017-02-21T23:44:49Z  Musical Instruments
# ...                    ...                   ...                  ...
# 328960             4 hours  2015-04-20T22:15:17Z      Web Development
# 552700             5 hours  2015-10-26T20:04:21Z  Musical Instruments
# 631754           6.5 hours  2015-11-11T18:55:45Z      Web Development
# 1225194            2 hours  2017-05-26T16:45:55Z     Business Finance
# 964478           1.5 hours  2016-09-26T22:19:48Z       Graphic Design
#
# [3682 rows x 10 columns]

# %%
df.shape
# Out:
# (3682, 10)

# %% [markdown]
# ### Q. 1) What are all different subjects for which Udemy is offering courses ?

# %%
df.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %% [markdown]
# ## Q. 2) Which subject has the maximum number of courses.

# %%
df.subject.value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %% [markdown]
# ## Q. 3) Show all the courses which are Free of Cost.

# %%
df[df.is_paid==False]
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 286070           5 lecciones que todo guitarrista debe tomar    False  Free
# 696630     7 Ways A Beginner Guitarist Can Sound Better, ...    False  Free
# 955914     A beginner`s guide to fingerpicking and strumm...    False  Free
# 270976                                A how to guide in HTML    False  Free
# 1214144    ¡Triunfar en La Bolsa de Valores No Requiere d...    False  Free
# ...                                                      ...      ...   ...
# 552598     WordPress in under an hour - Create/manage you...    False  Free
# 1068590                       Wordpress Website Mastery 2017    False  Free
# 752706     Write quicker HTML5 and CSS 3; productivity ha...    False  Free
# 1257976    Your First 10 Guitar Lessons - Learn how to pl...    False  Free
# 1225194    Zoho Books Gestion Financière d'Entreprise pas...    False  Free
#
#            num_subscribers  num_reviews  num_lectures           level  \
# course_id
# 286070                4452          263            14  Beginner Level
# 696630                4529          193             7  Beginner Level
# 955914                3481           29            20  Beginner Level
# 270976                7318          205             8  Beginner Level
# 1214144                338            7             6  Beginner Level
# ...                    ...          ...           ...             ...
# 552598                6474           86            15      All Levels
# 1068590               5181           64            22  Beginner Level
# 752706               13016          286            15      All Levels
# 1257976                924            4            18  Beginner Level
# 1225194                229            0            33      All Levels
#
#           content_duration   published_timestamp              subject
# course_id
# 286070              1 hour  2014-08-23T05:08:14Z  Musical Instruments
# 696630             36 mins  2015-12-21T18:50:50Z  Musical Instruments
# 955914             2 hours  2016-09-13T21:51:59Z  Musical Instruments
# 270976             35 mins  2014-08-10T20:19:10Z      Web Development
# 1214144             1 hour  2017-05-30T14:30:12Z     Business Finance
# ...                    ...                   ...                  ...
# 552598              1 hour  2015-07-15T00:21:56Z      Web Development
# 1068590          2.5 hours  2017-01-18T17:01:40Z      Web Development
# 752706           1.5 hours  2016-03-03T17:45:31Z      Web Development
# 1257976             1 hour  2017-06-29T00:29:36Z  Musical Instruments
# 1225194            2 hours  2017-05-26T16:45:55Z     Business Finance
#
# [310 rows x 10 columns]

# %%
df['price'].value_counts()
# Out:
# 20      830
# 50      468
# Free    310
# 200     295
# 40      217
# 30      170
# 25      154
# 95      152
# 100     133
# 195     127
# 35      116
# 150      88
# 45       83
# 75       81
# 60       75
# 120      37
# 55       35
# 85       31
# 65       30
# 125      30
# 80       29
# 145      27
# 70       26
# 90       19
# 180      17
# 115      16
# 175      13
# 105      11
# 140      10
# 190      10
# 110       8
# 135       8
# 185       6
# 165       6
# 170       5
# 160       4
# 130       3
# 155       2
# Name: price, dtype: int64

# %% [markdown]
# ## Q. 4) Show all the courses which are Paid.

# %%
df[df.is_paid==True]
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 288942     #1 Piano Hand Coordination: Play 10th Ballad i...     True    35
# 1170074    #10 Hand Coordination - Transfer Chord Ballad ...     True    75
# 1193886    #12 Hand Coordination: Let your Hands dance wi...     True    75
# 1116700    #4 Piano Hand Coordination: Fun Piano Runs in ...     True    75
# 1120410    #5  Piano Hand Coordination:  Piano Runs in 2 ...     True    75
# ...                                                      ...      ...   ...
# 498488     Your First Successful Forex Trades - With Case...     True   200
# 328960     Your Own Site in 45 Min: The Complete Wordpres...     True   120
# 552700       Your Second Course on Piano: Two Handed Playing     True    70
# 631754     Zend Framework 2: Learn the PHP framework ZF2 ...     True    40
# 964478                   Zombie Apocalypse Photoshop Actions     True    50
#
#            num_subscribers  num_reviews  num_lectures               level  \
# course_id
# 288942                3137           18            68          All Levels
# 1170074               1593            1            41  Intermediate Level
# 1193886                482            1            47  Intermediate Level
# 1116700                850            3            43  Intermediate Level
# 1120410                940            3            32  Intermediate Level
# ...                    ...          ...           ...                 ...
# 498488                1079           34            16          All Levels
# 328960                1566           29            36          All Levels
# 552700                1018           12            22      Beginner Level
# 631754                 723          130            37          All Levels
# 964478                  12            1            15          All Levels
#
#           content_duration   published_timestamp              subject
# course_id
# 288942           1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1170074             1 hour  2017-04-12T19:06:34Z  Musical Instruments
# 1193886          1.5 hours  2017-04-26T18:34:57Z  Musical Instruments
# 1116700             1 hour  2017-02-21T23:48:18Z  Musical Instruments
# 1120410            37 mins  2017-02-21T23:44:49Z  Musical Instruments
# ...                    ...                   ...                  ...
# 498488           2.5 hours  2015-05-26T20:48:48Z     Business Finance
# 328960             4 hours  2015-04-20T22:15:17Z      Web Development
# 552700             5 hours  2015-10-26T20:04:21Z  Musical Instruments
# 631754           6.5 hours  2015-11-11T18:55:45Z      Web Development
# 964478           1.5 hours  2016-09-26T22:19:48Z       Graphic Design
#
# [3372 rows x 10 columns]

# %% [markdown]
# ## Q. 5) Which are Top Selling Courses ?

# %%
df.sort_values('num_subscribers',ascending=False).head(5)
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 41295                   Learn HTML5 Programming From Scratch    False  Free
# 59014                         Coding for Entrepreneurs Basic    False  Free
# 625204                            The Web Developer Bootcamp     True   200
# 173548     Build Your First Website in 1 Week with HTML5 ...    False  Free
# 764164                 The Complete Web Developer Course 2.0     True   200
#
#            num_subscribers  num_reviews  num_lectures           level  \
# course_id
# 41295               268923         8629            45      All Levels
# 59014               161029          279            27  Beginner Level
# 625204              121584        27445           342      All Levels
# 173548              120291         5924            30  Beginner Level
# 764164              114512        22412           304      All Levels
#
#           content_duration   published_timestamp          subject
# course_id
# 41295           10.5 hours  2013-02-14T07:03:41Z  Web Development
# 59014            3.5 hours  2013-06-09T15:51:55Z  Web Development
# 625204            43 hours  2015-11-02T21:13:27Z  Web Development
# 173548             3 hours  2014-04-08T16:21:30Z  Web Development
# 764164          30.5 hours  2016-03-08T22:28:36Z  Web Development

# %% [markdown]
# ## Q. 6) Which are Least Selling Courses ?

# %%
df.sort_values('num_subscribers').head(10)
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 1233314                        Building a Balanced Scorecard     True    50
# 1232282            The Cash Flow Statement - An Introduction     True    50
# 1275872                      The Complete Adobe Spark Course     True   150
# 726314          Create Beautiful Image Maps for Your Website     True    20
# 715476           The Cuckoo Strategy to get European Funding     True   160
# 1187084    Forex how traders beat the markest with little...     True   100
# 185526                                MicroStation - Células     True    20
# 185526                                MicroStation - Células     True    20
# 1232390                                     Corporate Ethics     True   100
# 995384     Professional Business Logo Design Using Free O...     True    20
#
#            num_subscribers  num_reviews  num_lectures               level  \
# course_id
# 1233314                  0            0            11  Intermediate Level
# 1232282                  0            0            10      Beginner Level
# 1275872                  0            0            29          All Levels
# 726314                   0            0             8  Intermediate Level
# 715476                   0            0             6          All Levels
# 1187084                  0            0            16          All Levels
# 185526                   0            0             9      Beginner Level
# 185526                   0            0             9      Beginner Level
# 1232390                  0            0            13      Beginner Level
# 995384                   0            0             5          All Levels
#
#           content_duration   published_timestamp           subject
# course_id
# 1233314            2 hours  2017-07-03T21:38:22Z  Business Finance
# 1232282          1.5 hours  2017-06-28T16:05:51Z  Business Finance
# 1275872            2 hours  2017-07-03T17:39:57Z    Graphic Design
# 726314             37 mins  2016-01-18T17:56:36Z    Graphic Design
# 715476              1 hour  2016-01-06T02:38:23Z  Business Finance
# 1187084             1 hour  2017-07-06T21:16:13Z  Business Finance
# 185526             37 mins  2014-04-15T21:48:55Z    Graphic Design
# 185526             37 mins  2014-04-15T21:48:55Z    Graphic Design
# 1232390          3.5 hours  2017-07-03T21:39:13Z  Business Finance
# 995384             37 mins  2016-10-31T16:09:48Z    Graphic Design

# %% [markdown]
# ## Q. 7) Show all courses of Graphic Design where the price is below 100 ?

# %%
df.head(1)
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 288942     #1 Piano Hand Coordination: Play 10th Ballad i...     True    35
#
#            num_subscribers  num_reviews  num_lectures       level  \
# course_id
# 288942                3137           18            68  All Levels
#
#           content_duration   published_timestamp              subject
# course_id
# 288942           1.5 hours  2014-09-18T05:07:05Z  Musical Instruments

# %%
df.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
df[(df.subject=='Graphic Design') & (df.price >= '100')]
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 206592     :::Beginners Guide To Creating Amazing Images ...     True    25
# 1165268    15  Motion Graphic Elements in After Effect (S...     True    30
# 1164876    3DS MAX - Learn 3Ds MAX tutorial for Beginners...     True    20
# 599652                        48 Logo Designs and Techniques     True    20
# 1269190            7 Secrets To Designing In Black and White     True   100
# ...                                                      ...      ...   ...
# 1131780    Whiteboard Animation, Beginner To Expert - In ...     True    20
# 908664     Word Swag : Create Stunning Images with the Wo...     True   100
# 1122306           Wordpress: Comment utiliser le thème FABLE     True    20
# 144222     YOU can Draw, Shade and Paint a Mixed Media Gi...     True    30
# 964478                   Zombie Apocalypse Photoshop Actions     True    50
#
#            num_subscribers  num_reviews  num_lectures               level  \
# course_id
# 206592                  72            5            17      Beginner Level
# 1165268                  8            0            20  Intermediate Level
# 1164876                785            2            29          All Levels
# 599652                 113            9            48          All Levels
# 1269190               1000            1            12          All Levels
# ...                    ...          ...           ...                 ...
# 1131780               1343           25            16          All Levels
# 908664                2416           19            14          All Levels
# 1122306                  1            0            10      Beginner Level
# 144222                1249           44            19      Beginner Level
# 964478                  12            1            15          All Levels
#
#           content_duration   published_timestamp         subject
# course_id
# 206592              1 hour  2014-04-29T19:50:31Z  Graphic Design
# 1165268            3 hours  2017-04-11T04:27:34Z  Graphic Design
# 1164876          4.5 hours  2017-04-18T16:45:59Z  Graphic Design
# 599652             9 hours  2015-09-15T00:23:14Z  Graphic Design
# 1269190          1.5 hours  2017-06-27T19:55:18Z  Graphic Design
# ...                    ...                   ...             ...
# 1131780             1 hour  2017-03-14T20:52:30Z  Graphic Design
# 908664              1 hour  2016-08-09T17:56:53Z  Graphic Design
# 1122306            39 mins  2017-03-07T16:53:27Z  Graphic Design
# 144222             3 hours  2014-01-28T02:30:26Z  Graphic Design
# 964478           1.5 hours  2016-09-26T22:19:48Z  Graphic Design
#
# [603 rows x 10 columns]

# %% [markdown]
# ## Q. 8) List out all the courses that are related to 'Python'.

# %%
df[df.course_title.str.contains('Python')]
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 599504     Advanced Scalable Python Web Development Using...     True   120
# 47963      Coding for Entrepreneurs: Learn Python, Django...     True   195
# 631128     Complete Python Web Course: Build 8 Python Web...     True   110
# 186096     Core: A Web App Reference Guide for Django, Py...     True   195
# 394832     Fun and creative web engineering with Python a...    False  Free
# 1038538              Introduction to QGIS Python Programming     True    85
# 902888             Investment Portfolio Analysis with Python     True    50
# 391546           Learn Python and Django: Payment Processing     True    70
# 1063722              Learn Python Django - A Hands-On Course     True    50
# 546848     Learn to code in Python and learn Adobe Photos...     True    50
# 368340       Professional Python Web Development Using Flask     True   120
# 1035940    Professional RESTful API Design using Python F...     True   120
# 270808                         Projects in Django and Python     True    60
# 1170894    Python Algo Stock Trading: Automate Your Trading!     True    95
# 1070886           Python Algo Trading: FX Trading with Oanda     True   200
# 1196544     Python Algo Trading: Sentiment Trading with News     True   200
# 822444     Python and Django Full Stack Web Developer Boo...     True   200
# 477702     Python for Beginners: Python Programming Langu...     True   150
# 1035472    Python for Finance: Investment Fundamentals & ...     True   195
# 529828                        Python for Trading & Investing     True    95
# 70640      Python Programming: Create an Digital Marketpl...     True   195
# 523312                                Python Web Programming     True   100
# 1088656            Quantitative Trading Analysis with Python     True    50
# 970600                       REST APIs with Flask and Python     True   110
# 815482                  Stock Technical Analysis with Python     True    50
# 938560     The Complete Ethical Hacking Course 2.0: Pytho...     True   195
# 76052      Try Django 1.9 | Build a Blog and Learn Python...     True    50
# 16646                            Web Programming with Python     True    50
# 574082           Web Scraping with Python, Ruby & import. io     True    75
#
#            num_subscribers  num_reviews  num_lectures               level  \
# course_id
# 599504                1299           56            71  Intermediate Level
# 47963                23412          799           251          All Levels
# 631128                7489          941           173          All Levels
# 186096                2497           98           154          All Levels
# 394832               10917          319            25          All Levels
# 1038538                197           26            28      Beginner Level
# 902888                 209           13            37          All Levels
# 391546               17714          198            23          All Levels
# 1063722               1339           21            18      Beginner Level
# 546848                1132            1            29          All Levels
# 368340                3420          489           102      Beginner Level
# 1035940                578           25            36  Intermediate Level
# 270808                1764           53            28          All Levels
# 1170894               1165           21            41      Beginner Level
# 1070886                453           42            33  Intermediate Level
# 1196544                294           19            42          All Levels
# 822444               11832         1883           191          All Levels
# 477702                6153          125            84      Beginner Level
# 1035472               3811          278           103          All Levels
# 529828                 638           25            36          All Levels
# 70640                 4198          145           161          All Levels
# 523312                1020           46            60      Beginner Level
# 1088656                256           17            49          All Levels
# 970600                5151          737           115  Intermediate Level
# 815482                 409           35            46          All Levels
# 938560                7827          268            66          All Levels
# 76052                 7407          172           147          All Levels
# 16646                35267          217            53          All Levels
# 574082                 973           50            46          All Levels
#
#           content_duration   published_timestamp           subject
# course_id
# 599504            14 hours  2016-08-11T22:09:24Z   Web Development
# 47963             45 hours  2013-04-08T00:46:14Z   Web Development
# 631128            16 hours  2015-11-08T20:57:35Z   Web Development
# 186096            26 hours  2014-05-29T00:58:43Z   Web Development
# 394832             2 hours  2015-06-09T19:51:50Z   Web Development
# 1038538          3.5 hours  2016-12-22T00:11:22Z   Web Development
# 902888             7 hours  2016-07-13T21:40:32Z  Business Finance
# 391546           3.5 hours  2015-02-09T15:37:56Z   Web Development
# 1063722            2 hours  2017-01-18T21:53:34Z   Web Development
# 546848             2 hours  2015-07-08T00:15:12Z    Graphic Design
# 368340          14.5 hours  2015-03-04T00:10:36Z   Web Development
# 1035940          4.5 hours  2017-01-11T21:15:25Z   Web Development
# 270808           6.5 hours  2014-10-21T07:58:07Z   Web Development
# 1170894          2.5 hours  2017-05-28T23:41:03Z  Business Finance
# 1070886            3 hours  2017-03-14T00:39:45Z  Business Finance
# 1196544            7 hours  2017-04-28T16:41:44Z  Business Finance
# 822444          31.5 hours  2017-02-24T18:40:55Z   Web Development
# 477702             5 hours  2015-06-14T18:18:57Z   Web Development
# 1035472          6.5 hours  2017-03-30T22:17:09Z  Business Finance
# 529828             5 hours  2015-06-17T22:23:31Z  Business Finance
# 70640             26 hours  2013-10-20T19:53:28Z   Web Development
# 523312             6 hours  2015-07-01T21:46:36Z   Web Development
# 1088656          5.5 hours  2017-01-27T17:11:28Z  Business Finance
# 970600          12.5 hours  2016-11-06T19:00:38Z   Web Development
# 815482             8 hours  2016-04-12T00:40:03Z  Business Finance
# 938560            11 hours  2016-09-26T15:08:29Z   Web Development
# 76052             20 hours  2014-03-04T07:12:21Z   Web Development
# 16646              4 hours  2012-04-25T00:01:43Z   Web Development
# 574082           4.5 hours  2015-08-09T22:16:41Z   Web Development

# %%
len(df[df.course_title.str.contains('Python')])
# Out:
# 29

# %% [markdown]
# ## Q. 9) What are courses that were published in the year 2015 ?

# %%
df.head(1)
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 288942     #1 Piano Hand Coordination: Play 10th Ballad i...     True    35
#
#            num_subscribers  num_reviews  num_lectures       level  \
# course_id
# 288942                3137           18            68  All Levels
#
#           content_duration   published_timestamp              subject
# course_id
# 288942           1.5 hours  2014-09-18T05:07:05Z  Musical Instruments

# %%
df['published_timestamp'] = pd.to_datetime(df.published_timestamp)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3682 entries, 288942 to 964478
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_title         3682 non-null   object
#  1   is_paid              3682 non-null   bool
#  2   price                3682 non-null   object
#  3   num_subscribers      3682 non-null   int64
#  4   num_reviews          3682 non-null   int64
#  5   num_lectures         3682 non-null   int64
#  6   level                3682 non-null   object
#  7   content_duration     3682 non-null   object
#  8   published_timestamp  3682 non-null   datetime64[ns, UTC]
#  9   subject              3682 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), int64(3), object(5)
# memory usage: 291.3+ KB

# %%
df['Year'] = df['published_timestamp'].dt.year

# %%
df.head(1)
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 288942     #1 Piano Hand Coordination: Play 10th Ballad i...     True    35
#
#            num_subscribers  num_reviews  num_lectures       level  \
# course_id
# 288942                3137           18            68  All Levels
#
#           content_duration       published_timestamp              subject  \
# course_id
# 288942           1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments
#
#            Year
# course_id
# 288942     2014

# %%
df[df.Year==2015]
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 591880     1 - Concepts of Statistics For Beginners Step ...     True   200
# 302450           10 Numbers Every Business Owner Should Know     True    20
# 384928     101 Blues riffs - learn how the harmonica supe...     True   200
# 550842     16 Guitar Chords to Jam With - (Beginner - Int...     True    20
# 486240         2 Easy Steps To Investment And Avoiding Traps     True    20
# ...                                                      ...      ...   ...
# 551170                            Your First Course on Piano     True    70
# 498488     Your First Successful Forex Trades - With Case...     True   200
# 328960     Your Own Site in 45 Min: The Complete Wordpres...     True   120
# 552700       Your Second Course on Piano: Two Handed Playing     True    70
# 631754     Zend Framework 2: Learn the PHP framework ZF2 ...     True    40
#
#            num_subscribers  num_reviews  num_lectures               level  \
# course_id
# 591880                 273            4            15      Beginner Level
# 302450                  13            1             9          All Levels
# 384928                1350           65            55  Intermediate Level
# 550842                1224           19            20      Beginner Level
# 486240                 828            1            20          All Levels
# ...                    ...          ...           ...                 ...
# 551170                2002           34            33      Beginner Level
# 498488                1079           34            16          All Levels
# 328960                1566           29            36          All Levels
# 552700                1018           12            22      Beginner Level
# 631754                 723          130            37          All Levels
#
#           content_duration       published_timestamp              subject  \
# course_id
# 591880             31 mins 2015-08-30 22:48:34+00:00     Business Finance
# 302450              1 hour 2015-03-08 19:11:24+00:00     Business Finance
# 384928           6.5 hours 2015-01-04 21:14:31+00:00  Musical Instruments
# 550842              1 hour 2015-07-10 19:53:56+00:00  Musical Instruments
# 486240              1 hour 2015-04-27 23:18:59+00:00     Business Finance
# ...                    ...                       ...                  ...
# 551170             4 hours 2015-07-16 17:07:49+00:00  Musical Instruments
# 498488           2.5 hours 2015-05-26 20:48:48+00:00     Business Finance
# 328960             4 hours 2015-04-20 22:15:17+00:00      Web Development
# 552700             5 hours 2015-10-26 20:04:21+00:00  Musical Instruments
# 631754           6.5 hours 2015-11-11 18:55:45+00:00      Web Development
#
#            Year
# course_id
# 591880     2015
# 302450     2015
# 384928     2015
# 550842     2015
# 486240     2015
# ...         ...
# 551170     2015
# 498488     2015
# 328960     2015
# 552700     2015
# 631754     2015
#
# [1014 rows x 11 columns]

# %% [markdown]
# ## Q. 10) What is the Max. Number of Subscribers for Each Level of courses ?

# %%
df.head(1)
# Out:
#                                                 course_title  is_paid price  \
# course_id
# 288942     #1 Piano Hand Coordination: Play 10th Ballad i...     True    35
#
#            num_subscribers  num_reviews  num_lectures       level  \
# course_id
# 288942                3137           18            68  All Levels
#
#           content_duration       published_timestamp              subject  \
# course_id
# 288942           1.5 hours 2014-09-18 05:07:05+00:00  Musical Instruments
#
#            Year
# course_id
# 288942     2014

# %%
df.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
df.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
df.groupby('level')['num_subscribers'].min()
# Out:
# level
# All Levels            0
# Beginner Level        0
# Expert Level          1
# Intermediate Level    0
# Name: num_subscribers, dtype: int64

# %%
df.groupby('level').max()
# Out:
#                                                          course_title  \
# level
# All Levels                              ６時間でインターバンク市場を攻略！最短距離でトレード基礎力
# Beginner Level             ７日でマスター  ビギナー向け Adobe Illustrator　どきどきセミナー
# Expert Level        [Value Investing] Where White People Keep Thei...
# Intermediate Level                           株式投資で本当のテクニカル分析ができるようになる
#
#                     is_paid price  num_subscribers  num_reviews  num_lectures  \
# level
# All Levels             True  Free           268923        27445           544
# Beginner Level         True  Free           161029         5924           779
# Expert Level           True    95             5172          249           157
# Intermediate Level     True  Free            29167         3326           320
#
#                    content_duration       published_timestamp  \
# level
# All Levels                9.5 hours 2017-07-06 21:16:13+00:00
# Beginner Level            9.5 hours 2017-07-06 21:46:30+00:00
# Expert Level                9 hours 2017-07-04 18:08:01+00:00
# Intermediate Level        9.5 hours 2017-07-05 04:41:54+00:00
#
#                             subject  Year
# level
# All Levels          Web Development  2017
# Beginner Level      Web Development  2017
# Expert Level        Web Development  2017
# Intermediate Level  Web Development  2017

# %%
df.groupby('level').min()
# Out:
#                                                          course_title  \
# level
# All Levels          #1 Piano Hand Coordination: Play 10th Ballad i...
# Beginner Level      1 - Concepts of Statistics For Beginners Step ...
# Expert Level                               Adobe InDesign CC Advanced
# Intermediate Level  #10 Hand Coordination - Transfer Chord Ballad ...
#
#                     is_paid price  num_subscribers  num_reviews  num_lectures  \
# level
# All Levels            False   100                0            0             0
# Beginner Level        False   100                0            0             0
# Expert Level           True   100                1            0             6
# Intermediate Level    False   100                0            0             5
#
#                    content_duration       published_timestamp  \
# level
# All Levels                        0 2011-07-09 05:43:31+00:00
# Beginner Level               1 hour 2012-06-15 17:00:33+00:00
# Expert Level                 1 hour 2013-02-24 04:47:36+00:00
# Intermediate Level           1 hour 2012-05-21 18:22:09+00:00
#
#                              subject  Year
# level
# All Levels          Business Finance  2011
# Beginner Level      Business Finance  2012
# Expert Level        Business Finance  2013
# Intermediate Level  Business Finance  2012
